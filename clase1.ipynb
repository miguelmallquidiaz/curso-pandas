# %% [markdown]
# ## Descargar la librería

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Dataframe

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Importar la librería

# %%
import pandas as pd

# %%
# Es una lista
df = pd.DataFrame(
    {
        "Nombre": ["Maria", "Miguel", "Juan"],
        "Edad": [12, 11, 15],
        "Genero": ["M", "H", "H"],
    }
)

# %%
df
# Out:
#    Nombre  Edad Genero
# 0   Maria    12      M
# 1  Miguel    11      H
# 2    Juan    15      H

# %% [markdown]
# ## Filtrado de columna

# %%
# data series es una selección de nuestra columna
df["Nombre"]
# Out:
# 0     Maria
# 1    Miguel
# 2      Juan
# Name: Nombre, dtype: object

# %% [markdown]
# ## El tipo de cado de cada columna

# %%
df.dtypes
# Out:
# Nombre    object
# Edad       int64
# Genero    object
# dtype: object

# %% [markdown]
# ## Obtener el máximo y mínimo

# %%
print("edad máxima", df["Edad"].max())
print("edad mínima", df["Edad"].min())
# Out:
# edad máxima 15
# edad mínima 11

# %% [markdown]
# ## Descripción estadística

# %%
df.describe()
# Out:
#             Edad
# count   3.000000
# mean   12.666667
# std     2.081666
# min    11.000000
# 25%    11.500000
# 50%    12.000000
# 75%    13.500000
# max    15.000000

# %% [markdown]
# ## Función info

# %%
# NAN representa valores nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nombre  3 non-null      object
#  1   Edad    3 non-null      int64
#  2   Genero  3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
